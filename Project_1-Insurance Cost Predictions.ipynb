# %% [markdown]
# <a href="https://colab.research.google.com/github/shahjan49/Machine-Learning-/blob/main/Project_1-Insurance%20Cost%20Predictions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Gathering the data

# %%
#importing the packages
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/insurance.csv")

# %%
data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %% [markdown]
# Data preprocessing

# %%
#convert the categorical variables into numerical format - using One Hot Encoding technique
data['sex']=data['sex'].apply({'male':0,'female':1}.get)

# %%
data.head()
# Out:
#    age  sex   bmi  children smoker     region  expenses
# 0   19    1  27.9         0    yes  southwest  16884.92
# 1   18    0  33.8         1     no  southeast   1725.55
# 2   28    0  33.0         3     no  southeast   4449.46
# 3   33    0  22.7         0     no  northwest  21984.47
# 4   32    0  28.9         0     no  northwest   3866.86

# %%
data['smoker']=data['smoker'].apply({'yes':1,'no':0}.get)
data['region']=data['region'].apply({'southeast':1,'southwest':2,'northeast':3,'northwest':4}.get)

# %%
data.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0   19    1  27.9         0       1       2  16884.92
# 1   18    0  33.8         1       0       1   1725.55
# 2   28    0  33.0         3       0       1   4449.46
# 3   33    0  22.7         0       0       4  21984.47
# 4   32    0  28.9         0       0       4   3866.86

# %% [markdown]
# Dividing the clean data into dependent(y) and independent(x) variables

# %%
x=data[['age','sex','bmi','children','smoker','region']] #independent parameters
y=data['expenses'] #dependent parameter

# %% [markdown]
# Splitting the clean data into training and testing set

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %% [markdown]
# Creating the MLM using LinearRegression algorithm

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression() #activating the linear regression algorithm

# %%
regression.fit(x_train,y_train) #.fit() used for training the MLM
# Out:
# LinearRegression()

# %%
predictions=regression.predict(x_test) #.predict() used to predict the future values

# %%
#accuracy of MLM
regression.score(x,y)
# Out:
# 0.7502305465363868

# %% [markdown]
# Calculating the insurance cost for a new customer

# %%
#creating dataset for new customer
data_new={'age':25,'sex':0,'bmi':23,'children':0,'smoker':0,'region':3}

# %%
index=[1]
my_data=pd.DataFrame(data_new,index)

# %%
my_data
# Out:
#    age  sex  bmi  children  smoker  region
# 1   25    0   23         0       0       3

# %%
#predicting the insurance cost for a new customer
new_predictions=regression.predict(my_data)
print("the health insurance cost for the new customer is ", new_predictions)
# Out:
# the health insurance cost for the new customer is  [1988.88540771]
